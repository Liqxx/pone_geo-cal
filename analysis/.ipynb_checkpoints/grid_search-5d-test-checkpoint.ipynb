# %% [markdown]
# Cobalt 08 - Screen session

# %%
# icecube 
from icecube.dataclasses import *
from icecube.icetray import OMKey
from icecube import dataio, dataclasses, simclasses

# usual
import os
import sys
import copy
import numpy as np
from scipy.interpolate import interp1d, interp2d

# plotting
# %matplotlib notebook
import matplotlib as mpl
from matplotlib import rcParams
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.pyplot import cm
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
from mpl_toolkits.axes_grid1 import make_axes_locatable

# plt.style.use('/home/fhenningsen/plotformat.rc')

# %%
#Using new GCD:
geometry = dataio.I3File("/home/fhenningsen/gcd/physics_volume_GCD.i3.bz2")
gframe = geometry.pop_frame()  
geo = gframe["I3Geometry"] #access geo file via key

#ceate a general event dictionary with 2D array (charge,time) as values
event = {} 
all_dom_keys = []
for i in geo.omgeo.keys():
    if i.pmt == 0 and i.string < 87 and i.om <= 60:
        all_dom_keys.append(i)
        
for i in all_dom_keys:
    event[i] = []

# %%
def param_string(abso, sca, domeff, p0, p1, Nph, N, pocam):
    return 'ABS-%.3f_SCA-%.3f_DOME-%.3f_P0-%.3f_P1-%.3f_NPH-%.3e_N-%i_POCAM-%s' %(abso, sca,
                                                                                  domeff, p0, p1,
                                                                                  Nph, N,
                                                                                  pocam)

# %% [markdown]
# ### Define parameter space

# %%
direc = '/data/user/fhenningsen/deepcore_data/read_3d-domeff-p0-p1-8/'

# %%
# get simulation set parameters
params = np.load(os.path.join(direc, 'PARAMS.npy')).item()

pocams     = params['pocams']
pocam_keys = params['pocam_keys']
truth_arr  = params['truth_arr']
truth_str  = params['truth_string']

# get dictionaries for values
# data / scan
scan_dict  = params['scan_dict']
scan_N     = scan_dict['n']
scan_Nph   = scan_dict['nph']
scan_abs   = scan_dict['abs']
scan_sca   = scan_dict['sca']
scan_dome  = scan_dict['domeff']
scan_p0    = scan_dict['p0']
scan_p1    = scan_dict['p1']
# truth
truth_dict = params['truth_dict']
t_N     = truth_dict['n']
t_Nph   = truth_dict['nph']
t_abs   = truth_dict['abs']
t_sca   = truth_dict['sca']
t_dome  = truth_dict['domeff']
t_p0    = truth_dict['p0']
t_p1    = truth_dict['p1']

# %%
params
# Out:
# {'pocam_keys': [OMKey(87,84,0),
#   OMKey(88,72,0),
#   OMKey(89,38,0),
#   OMKey(90,100,0),
#   OMKey(91,50,0),
#   OMKey(92,28,0),
#   OMKey(93,64,0)],
#  'pocams': array(['87-84', '88-72', '89-38', '90-100', '91-50', '92-28', '93-64'],
#        dtype='|S6'),
#  'scan_dict': {'abs': array([1.]),
#   'domeff': array([0.9  , 0.929, 0.957, 0.986, 1.014, 1.043, 1.071, 1.1  ]),
#   'n': array([100.]),
#   'nph': array([1.e+08]),
#   'p0': array([-1.   , -0.714, -0.429, -0.143,  0.143,  0.429,  0.714,  1.   ]),
#   'p1': array([-0.2  , -0.129, -0.057,  0.014,  0.086,  0.157,  0.229,  0.3  ]),
#   'sca': array([1.])},
#  'time_bins': 5000,
#  'truth_arr': [array([1.]),
#   array([1.]),
#   array([1.01]),
#   array([-0.03]),
#   array([0.05]),
#   array([100.])],
#  'truth_dict': {'abs': array([1.]),
#   'domeff': array([1.01]),
#   'n': array([100.]),
#   'nph': array([1.e+08]),
#   'p0': array([-0.03]),
#   'p1': array([0.05]),
#   'sca': array([1.])},
#  'truth_string': 'TRUTH_ABS-1.000_SCA-1.000_DOME-1.010_P0--0.030_P1-0.050_N-100'}

# %% [markdown]
# ### Define bin size

# %%
binsize    = 20 # ns
n_bins_old = 5000 # in 1ns bins

smart_binning = True # enables quadratic binning of time profiles

if not smart_binning:
    n_bins_new = 5000/binsize
    time_bins  = np.linspace(0, n_bins_old, (n_bins_new+1))
    print 'Using binsize of', binsize, 'ns'
else:
    n_bins_new = 30
    print 'Using smart binning.'
# Out:
# Using smart binning.

# %% [markdown]
# ## Read in truth and data

# %%
data_binned          = {}
data_binned["truth"] = {}
data_binned["data"]  = {}
data_binned["index"] = {}
data_binned["bins"]  = {}

### Read in truth ###
for pocam in pocams:
    par_t = param_string(t_abs, t_sca, t_dome, t_p0, t_p1, t_Nph, t_N, pocam)
    data_tmp_1ns_binned = np.load(os.path.expanduser('%s/TRUTH_%s.npy'%(direc, par_t)))
    data_binned["truth"][pocam] = copy.deepcopy(event)
    data_binned["index"][pocam] = copy.deepcopy(event)
    data_binned["bins"][pocam]  = copy.deepcopy(event)
    
    for key in all_dom_keys:  #go through all DOMs
        d = data_tmp_1ns_binned.item().get(key)
        
        if not smart_binning:
            # re-sum bins to get new bins of size <binsize>
            data_tmp_binned = [sum(d[i*binsize : (i+1)*binsize]) for i in range(n_bins_new)]
        else:
            # get POCAM coordinates
            p   = pocam.split('-')
            pk  = OMKey(int(p[0]), int(p[1]), 0)
            p_x = geo.omgeo[pk].position.x
            p_y = geo.omgeo[pk].position.y
            p_z = geo.omgeo[pk].position.z

            # get DOM coordinates
            d_x = geo.omgeo[key].position.x
            d_y = geo.omgeo[key].position.y
            d_z = geo.omgeo[key].position.z

            # get distance POCAM/DOM
            distance = np.sqrt((d_x-p_x)**2 + (d_y-p_y)**2 + (d_z-p_z)**2)
            
            # get geometrical min time of photons
            c_ice = 3e8 / 1.32
            t_geo = int(np.floor(distance / c_ice * 1e9)) # [ns]
            idx   = next((i for i, x in enumerate(d) if x), None)
            data_binned["index"][pocam][key] = t_geo
            
            # get new smart bins
            smart_exp  = np.log(n_bins_old - t_geo) / np.log(n_bins_new)
            smart_bins = [i**smart_exp for i in range(n_bins_new + 1)]
            smart_bins = np.array([t_geo + int(round(i)) for i in smart_bins])
            data_binned["bins"][pocam][key] = smart_bins
            
            # re-sum data with smart bins
            data_tmp_binned = [sum(d[smart_bins[i]:smart_bins[i+1]]) for i in range(len(smart_bins) - 1)]
            
        # eventually append to final dict
        data_binned["truth"][pocam][key]  = np.array(data_tmp_binned) / float(t_N / scan_N) # average to data size

print "Truth finished. Starting data...\n"
    
### Read in data ###
for _abs in scan_abs:
    for sca in scan_sca:
        for dome in scan_dome:
            for p0 in scan_p0:
                for p1 in scan_p1:
                    
                    tag="{sca}_{dome}_{p0}_{p1}_{_abs}".format(sca=sca,dome=dome,p0=p0,p1=p1,_abs=_abs)
                    data_binned["data"][tag] = {}
                         
                    for pocam in pocams: 
                        par = param_string(_abs, sca, dome, p0, p1, scan_Nph, scan_N, pocam)
                        data_tmp_1ns_binned = np.load(os.path.expanduser('%s/%s.npy'%(direc, par)))
                        data_binned["data"][tag][pocam] = copy.deepcopy(event)

                        for key in all_dom_keys:  # go through all DOMs
                            d = data_tmp_1ns_binned.item().get(key)
                            if not smart_binning:
                                # re-sum bins to new binsize
                                data_tmp_binned = [sum(d[i*binsize : (i+1)*binsize]) for i in range(n_bins_new)]
                            else:
                                smart_bins = data_binned["bins"][pocam][key]
                                t_geo      = data_binned["index"][pocam][key]
                                # re-sum with new smart bins
                                data_tmp_binned = [sum(d[smart_bins[i]:smart_bins[i+1]]) for i in range(len(smart_bins) - 1)]
                            
                            data_binned["data"][tag][pocam][key]  = data_tmp_binned
                                
                    print "Parameter combo:", _abs, sca, dome, p0, p1, "done!"
print "FINISHED!"
# Out:
# Truth finished. Starting data...
#
# Parameter combo: 1.0 1.0 0.9 -1.0 -0.2 done!
# Parameter combo: 1.0 1.0 0.9 -1.0 -0.129 done!
# Parameter combo: 1.0 1.0 0.9 -1.0 -0.057 done!
# Parameter combo: 1.0 1.0 0.9 -1.0 0.014 done!
# Parameter combo: 1.0 1.0 0.9 -1.0 0.086 done!
# Parameter combo: 1.0 1.0 0.9 -1.0 0.157 done!
# Parameter combo: 1.0 1.0 0.9 -1.0 0.229 done!
# Parameter combo: 1.0 1.0 0.9 -1.0 0.3 done!
# Parameter combo: 1.0 1.0 0.9 -0.714 -0.2 done!
# Parameter combo: 1.0 1.0 0.9 -0.714 -0.129 done!
# Parameter combo: 1.0 1.0 0.9 -0.714 -0.057 done!
# Parameter combo: 1.0 1.0 0.9 -0.714 0.014 done!
# Parameter combo: 1.0 1.0 0.9 -0.714 0.086 done!
# Parameter combo: 1.0 1.0 0.9 -0.714 0.157 done!
# Parameter combo: 1.0 1.0 0.9 -0.714 0.229 done!
# Parameter combo: 1.0 1.0 0.9 -0.714 0.3 done!
# Parameter combo: 1.0 1.0 0.9 -0.429 -0.2 done!
# Parameter combo: 1.0 1.0 0.9 -0.429 -0.129 done!
# Parameter combo: 1.0 1.0 0.9 -0.429 -0.057 done!
# Parameter combo: 1.0 1.0 0.9 -0.429 0.014 done!
# Parameter combo: 1.0 1.0 0.9 -0.429 0.086 done!
# Parameter combo: 1.0 1.0 0.9 -0.429 0.157 done!
# Parameter combo: 1.0 1.0 0.9 -0.429 0.229 done!
# Parameter combo: 1.0 1.0 0.9 -0.429 0.3 done!
# Parameter combo: 1.0 1.0 0.9 -0.143 -0.2 done!
# Parameter combo: 1.0 1.0 0.9 -0.143 -0.129 done!
# Parameter combo: 1.0 1.0 0.9 -0.143 -0.057 done!
# Parameter combo: 1.0 1.0 0.9 -0.143 0.014 done!
# Parameter combo: 1.0 1.0 0.9 -0.143 0.086 done!
# Parameter combo: 1.0 1.0 0.9 -0.143 0.157 done!
# Parameter combo: 1.0 1.0 0.9 -0.143 0.229 done!
# Parameter combo: 1.0 1.0 0.9 -0.143 0.3 done!
# Parameter combo: 1.0 1.0 0.9 0.143 -0.2 done!
# Parameter combo: 1.0 1.0 0.9 0.143 -0.129 done!
# Parameter combo: 1.0 1.0 0.9 0.143 -0.057 done!
# Parameter combo: 1.0 1.0 0.9 0.143 0.014 done!
# Parameter combo: 1.0 1.0 0.9 0.143 0.086 done!
# Parameter combo: 1.0 1.0 0.9 0.143 0.157 done!
# Parameter combo: 1.0 1.0 0.9 0.143 0.229 done!
# Parameter combo: 1.0 1.0 0.9 0.143 0.3 done!
# Parameter combo: 1.0 1.0 0.9 0.429 -0.2 done!
# Parameter combo: 1.0 1.0 0.9 0.429 -0.129 done!
# Parameter combo: 1.0 1.0 0.9 0.429 -0.057 done!
# Parameter combo: 1.0 1.0 0.9 0.429 0.014 done!
# Parameter combo: 1.0 1.0 0.9 0.429 0.086 done!
# Parameter combo: 1.0 1.0 0.9 0.429 0.157 done!
# Parameter combo: 1.0 1.0 0.9 0.429 0.229 done!
# Parameter combo: 1.0 1.0 0.9 0.429 0.3 done!
# Parameter combo: 1.0 1.0 0.9 0.714 -0.2 done!
# Parameter combo: 1.0 1.0 0.9 0.714 -0.129 done!
# Parameter combo: 1.0 1.0 0.9 0.714 -0.057 done!
# Parameter combo: 1.0 1.0 0.9 0.714 0.014 done!
# Parameter combo: 1.0 1.0 0.9 0.714 0.086 done!
# Parameter combo: 1.0 1.0 0.9 0.714 0.157 done!
# Parameter combo: 1.0 1.0 0.9 0.714 0.229 done!
# Parameter combo: 1.0 1.0 0.9 0.714 0.3 done!
# Parameter combo: 1.0 1.0 0.9 1.0 -0.2 done!
# Parameter combo: 1.0 1.0 0.9 1.0 -0.129 done!
# Parameter combo: 1.0 1.0 0.9 1.0 -0.057 done!
# Parameter combo: 1.0 1.0 0.9 1.0 0.014 done!
# Parameter combo: 1.0 1.0 0.9 1.0 0.086 done!
# Parameter combo: 1.0 1.0 0.9 1.0 0.157 done!
# Parameter combo: 1.0 1.0 0.9 1.0 0.229 done!
# Parameter combo: 1.0 1.0 0.9 1.0 0.3 done!
# Parameter combo: 1.0 1.0 0.929 -1.0 -0.2 done!
# Parameter combo: 1.0 1.0 0.929 -1.0 -0.129 done!
# Parameter combo: 1.0 1.0 0.929 -1.0 -0.057 done!
# Parameter combo: 1.0 1.0 0.929 -1.0 0.014 done!
# Parameter combo: 1.0 1.0 0.929 -1.0 0.086 done!
# Parameter combo: 1.0 1.0 0.929 -1.0 0.157 done!
# Parameter combo: 1.0 1.0 0.929 -1.0 0.229 done!
# Parameter combo: 1.0 1.0 0.929 -1.0 0.3 done!
# Parameter combo: 1.0 1.0 0.929 -0.714 -0.2 done!
# Parameter combo: 1.0 1.0 0.929 -0.714 -0.129 done!
# Parameter combo: 1.0 1.0 0.929 -0.714 -0.057 done!
# Parameter combo: 1.0 1.0 0.929 -0.714 0.014 done!
# Parameter combo: 1.0 1.0 0.929 -0.714 0.086 done!
# Parameter combo: 1.0 1.0 0.929 -0.714 0.157 done!
# Parameter combo: 1.0 1.0 0.929 -0.714 0.229 done!
# Parameter combo: 1.0 1.0 0.929 -0.714 0.3 done!
# Parameter combo: 1.0 1.0 0.929 -0.429 -0.2 done!
# Parameter combo: 1.0 1.0 0.929 -0.429 -0.129 done!
# Parameter combo: 1.0 1.0 0.929 -0.429 -0.057 done!
# Parameter combo: 1.0 1.0 0.929 -0.429 0.014 done!
# Parameter combo: 1.0 1.0 0.929 -0.429 0.086 done!
# Parameter combo: 1.0 1.0 0.929 -0.429 0.157 done!
# Parameter combo: 1.0 1.0 0.929 -0.429 0.229 done!
# Parameter combo: 1.0 1.0 0.929 -0.429 0.3 done!
# Parameter combo: 1.0 1.0 0.929 -0.143 -0.2 done!
# Parameter combo: 1.0 1.0 0.929 -0.143 -0.129 done!
# Parameter combo: 1.0 1.0 0.929 -0.143 -0.057 done!
# Parameter combo: 1.0 1.0 0.929 -0.143 0.014 done!
# Parameter combo: 1.0 1.0 0.929 -0.143 0.086 done!
# Parameter combo: 1.0 1.0 0.929 -0.143 0.157 done!
# Parameter combo: 1.0 1.0 0.929 -0.143 0.229 done!
# Parameter combo: 1.0 1.0 0.929 -0.143 0.3 done!
# Parameter combo: 1.0 1.0 0.929 0.143 -0.2 done!
# Parameter combo: 1.0 1.0 0.929 0.143 -0.129 done!
# Parameter combo: 1.0 1.0 0.929 0.143 -0.057 done!
# Parameter combo: 1.0 1.0 0.929 0.143 0.014 done!
# Parameter combo: 1.0 1.0 0.929 0.143 0.086 done!
# Parameter combo: 1.0 1.0 0.929 0.143 0.157 done!
# Parameter combo: 1.0 1.0 0.929 0.143 0.229 done!
# Parameter combo: 1.0 1.0 0.929 0.143 0.3 done!
# Parameter combo: 1.0 1.0 0.929 0.429 -0.2 done!
# Parameter combo: 1.0 1.0 0.929 0.429 -0.129 done!
# Parameter combo: 1.0 1.0 0.929 0.429 -0.057 done!
# Parameter combo: 1.0 1.0 0.929 0.429 0.014 done!
# Parameter combo: 1.0 1.0 0.929 0.429 0.086 done!
# Parameter combo: 1.0 1.0 0.929 0.429 0.157 done!
# Parameter combo: 1.0 1.0 0.929 0.429 0.229 done!
# Parameter combo: 1.0 1.0 0.929 0.429 0.3 done!
# Parameter combo: 1.0 1.0 0.929 0.714 -0.2 done!
# Parameter combo: 1.0 1.0 0.929 0.714 -0.129 done!
# Parameter combo: 1.0 1.0 0.929 0.714 -0.057 done!
# Parameter combo: 1.0 1.0 0.929 0.714 0.014 done!
# Parameter combo: 1.0 1.0 0.929 0.714 0.086 done!
# Parameter combo: 1.0 1.0 0.929 0.714 0.157 done!
# Parameter combo: 1.0 1.0 0.929 0.714 0.229 done!
# Parameter combo: 1.0 1.0 0.929 0.714 0.3 done!
# Parameter combo: 1.0 1.0 0.929 1.0 -0.2 done!
# Parameter combo: 1.0 1.0 0.929 1.0 -0.129 done!
# Parameter combo: 1.0 1.0 0.929 1.0 -0.057 done!
# Parameter combo: 1.0 1.0 0.929 1.0 0.014 done!
# Parameter combo: 1.0 1.0 0.929 1.0 0.086 done!
# Parameter combo: 1.0 1.0 0.929 1.0 0.157 done!
# Parameter combo: 1.0 1.0 0.929 1.0 0.229 done!
# Parameter combo: 1.0 1.0 0.929 1.0 0.3 done!
# Parameter combo: 1.0 1.0 0.957 -1.0 -0.2 done!
# Parameter combo: 1.0 1.0 0.957 -1.0 -0.129 done!
# Parameter combo: 1.0 1.0 0.957 -1.0 -0.057 done!
# Parameter combo: 1.0 1.0 0.957 -1.0 0.014 done!
# Parameter combo: 1.0 1.0 0.957 -1.0 0.086 done!
# Parameter combo: 1.0 1.0 0.957 -1.0 0.157 done!
# Parameter combo: 1.0 1.0 0.957 -1.0 0.229 done!
# Parameter combo: 1.0 1.0 0.957 -1.0 0.3 done!
# Parameter combo: 1.0 1.0 0.957 -0.714 -0.2 done!
# Parameter combo: 1.0 1.0 0.957 -0.714 -0.129 done!
# Parameter combo: 1.0 1.0 0.957 -0.714 -0.057 done!
# Parameter combo: 1.0 1.0 0.957 -0.714 0.014 done!
# Parameter combo: 1.0 1.0 0.957 -0.714 0.086 done!
# Parameter combo: 1.0 1.0 0.957 -0.714 0.157 done!
# Parameter combo: 1.0 1.0 0.957 -0.714 0.229 done!
# Parameter combo: 1.0 1.0 0.957 -0.714 0.3 done!
# Parameter combo: 1.0 1.0 0.957 -0.429 -0.2 done!
# Parameter combo: 1.0 1.0 0.957 -0.429 -0.129 done!
# Parameter combo: 1.0 1.0 0.957 -0.429 -0.057 done!
# Parameter combo: 1.0 1.0 0.957 -0.429 0.014 done!
# Parameter combo: 1.0 1.0 0.957 -0.429 0.086 done!
# Parameter combo: 1.0 1.0 0.957 -0.429 0.157 done!
# Parameter combo: 1.0 1.0 0.957 -0.429 0.229 done!
# Parameter combo: 1.0 1.0 0.957 -0.429 0.3 done!
# Parameter combo: 1.0 1.0 0.957 -0.143 -0.2 done!
# Parameter combo: 1.0 1.0 0.957 -0.143 -0.129 done!
# Parameter combo: 1.0 1.0 0.957 -0.143 -0.057 done!
# Parameter combo: 1.0 1.0 0.957 -0.143 0.014 done!
# Parameter combo: 1.0 1.0 0.957 -0.143 0.086 done!
# Parameter combo: 1.0 1.0 0.957 -0.143 0.157 done!
# Parameter combo: 1.0 1.0 0.957 -0.143 0.229 done!
# Parameter combo: 1.0 1.0 0.957 -0.143 0.3 done!
# Parameter combo: 1.0 1.0 0.957 0.143 -0.2 done!
# Parameter combo: 1.0 1.0 0.957 0.143 -0.129 done!
# Parameter combo: 1.0 1.0 0.957 0.143 -0.057 done!
# Parameter combo: 1.0 1.0 0.957 0.143 0.014 done!
# Parameter combo: 1.0 1.0 0.957 0.143 0.086 done!
# Parameter combo: 1.0 1.0 0.957 0.143 0.157 done!
# Parameter combo: 1.0 1.0 0.957 0.143 0.229 done!
# Parameter combo: 1.0 1.0 0.957 0.143 0.3 done!
# Parameter combo: 1.0 1.0 0.957 0.429 -0.2 done!
# Parameter combo: 1.0 1.0 0.957 0.429 -0.129 done!
# Parameter combo: 1.0 1.0 0.957 0.429 -0.057 done!
# Parameter combo: 1.0 1.0 0.957 0.429 0.014 done!
# Parameter combo: 1.0 1.0 0.957 0.429 0.086 done!
# Parameter combo: 1.0 1.0 0.957 0.429 0.157 done!
# Parameter combo: 1.0 1.0 0.957 0.429 0.229 done!
# Parameter combo: 1.0 1.0 0.957 0.429 0.3 done!
# Parameter combo: 1.0 1.0 0.957 0.714 -0.2 done!
# Parameter combo: 1.0 1.0 0.957 0.714 -0.129 done!
# Parameter combo: 1.0 1.0 0.957 0.714 -0.057 done!
# Parameter combo: 1.0 1.0 0.957 0.714 0.014 done!
# Parameter combo: 1.0 1.0 0.957 0.714 0.086 done!
# Parameter combo: 1.0 1.0 0.957 0.714 0.157 done!
# Parameter combo: 1.0 1.0 0.957 0.714 0.229 done!
# Parameter combo: 1.0 1.0 0.957 0.714 0.3 done!
# Parameter combo: 1.0 1.0 0.957 1.0 -0.2 done!
# Parameter combo: 1.0 1.0 0.957 1.0 -0.129 done!
# Parameter combo: 1.0 1.0 0.957 1.0 -0.057 done!
# Parameter combo: 1.0 1.0 0.957 1.0 0.014 done!
# Parameter combo: 1.0 1.0 0.957 1.0 0.086 done!
# Parameter combo: 1.0 1.0 0.957 1.0 0.157 done!
# Parameter combo: 1.0 1.0 0.957 1.0 0.229 done!
# Parameter combo: 1.0 1.0 0.957 1.0 0.3 done!
# Parameter combo: 1.0 1.0 0.986 -1.0 -0.2 done!
# Parameter combo: 1.0 1.0 0.986 -1.0 -0.129 done!
# Parameter combo: 1.0 1.0 0.986 -1.0 -0.057 done!
# Parameter combo: 1.0 1.0 0.986 -1.0 0.014 done!
# Parameter combo: 1.0 1.0 0.986 -1.0 0.086 done!
# Parameter combo: 1.0 1.0 0.986 -1.0 0.157 done!
# Parameter combo: 1.0 1.0 0.986 -1.0 0.229 done!
# Parameter combo: 1.0 1.0 0.986 -1.0 0.3 done!
# Parameter combo: 1.0 1.0 0.986 -0.714 -0.2 done!
# Parameter combo: 1.0 1.0 0.986 -0.714 -0.129 done!
# Parameter combo: 1.0 1.0 0.986 -0.714 -0.057 done!
# Parameter combo: 1.0 1.0 0.986 -0.714 0.014 done!
# Parameter combo: 1.0 1.0 0.986 -0.714 0.086 done!
# Parameter combo: 1.0 1.0 0.986 -0.714 0.157 done!
# Parameter combo: 1.0 1.0 0.986 -0.714 0.229 done!
# Parameter combo: 1.0 1.0 0.986 -0.714 0.3 done!
# Parameter combo: 1.0 1.0 0.986 -0.429 -0.2 done!
# Parameter combo: 1.0 1.0 0.986 -0.429 -0.129 done!
# Parameter combo: 1.0 1.0 0.986 -0.429 -0.057 done!
# Parameter combo: 1.0 1.0 0.986 -0.429 0.014 done!
# Parameter combo: 1.0 1.0 0.986 -0.429 0.086 done!
# Parameter combo: 1.0 1.0 0.986 -0.429 0.157 done!
# Parameter combo: 1.0 1.0 0.986 -0.429 0.229 done!
# Parameter combo: 1.0 1.0 0.986 -0.429 0.3 done!
# Parameter combo: 1.0 1.0 0.986 -0.143 -0.2 done!
# Parameter combo: 1.0 1.0 0.986 -0.143 -0.129 done!
# Parameter combo: 1.0 1.0 0.986 -0.143 -0.057 done!
# Parameter combo: 1.0 1.0 0.986 -0.143 0.014 done!
# Parameter combo: 1.0 1.0 0.986 -0.143 0.086 done!
# Parameter combo: 1.0 1.0 0.986 -0.143 0.157 done!
# Parameter combo: 1.0 1.0 0.986 -0.143 0.229 done!
# Parameter combo: 1.0 1.0 0.986 -0.143 0.3 done!
# Parameter combo: 1.0 1.0 0.986 0.143 -0.2 done!
# Parameter combo: 1.0 1.0 0.986 0.143 -0.129 done!
# Parameter combo: 1.0 1.0 0.986 0.143 -0.057 done!
# Parameter combo: 1.0 1.0 0.986 0.143 0.014 done!
# Parameter combo: 1.0 1.0 0.986 0.143 0.086 done!
# Parameter combo: 1.0 1.0 0.986 0.143 0.157 done!
# Parameter combo: 1.0 1.0 0.986 0.143 0.229 done!
# Parameter combo: 1.0 1.0 0.986 0.143 0.3 done!
# Parameter combo: 1.0 1.0 0.986 0.429 -0.2 done!
# Parameter combo: 1.0 1.0 0.986 0.429 -0.129 done!
# Parameter combo: 1.0 1.0 0.986 0.429 -0.057 done!
# Parameter combo: 1.0 1.0 0.986 0.429 0.014 done!
# Parameter combo: 1.0 1.0 0.986 0.429 0.086 done!
# Parameter combo: 1.0 1.0 0.986 0.429 0.157 done!
# Parameter combo: 1.0 1.0 0.986 0.429 0.229 done!
# Parameter combo: 1.0 1.0 0.986 0.429 0.3 done!
# Parameter combo: 1.0 1.0 0.986 0.714 -0.2 done!
# Parameter combo: 1.0 1.0 0.986 0.714 -0.129 done!
# Parameter combo: 1.0 1.0 0.986 0.714 -0.057 done!
# Parameter combo: 1.0 1.0 0.986 0.714 0.014 done!
# Parameter combo: 1.0 1.0 0.986 0.714 0.086 done!
# Parameter combo: 1.0 1.0 0.986 0.714 0.157 done!
# Parameter combo: 1.0 1.0 0.986 0.714 0.229 done!
# Parameter combo: 1.0 1.0 0.986 0.714 0.3 done!
# Parameter combo: 1.0 1.0 0.986 1.0 -0.2 done!
# Parameter combo: 1.0 1.0 0.986 1.0 -0.129 done!
# Parameter combo: 1.0 1.0 0.986 1.0 -0.057 done!
# Parameter combo: 1.0 1.0 0.986 1.0 0.014 done!
# Parameter combo: 1.0 1.0 0.986 1.0 0.086 done!
# Parameter combo: 1.0 1.0 0.986 1.0 0.157 done!
# Parameter combo: 1.0 1.0 0.986 1.0 0.229 done!
# Parameter combo: 1.0 1.0 0.986 1.0 0.3 done!
# Parameter combo: 1.0 1.0 1.014 -1.0 -0.2 done!
# Parameter combo: 1.0 1.0 1.014 -1.0 -0.129 done!
# Parameter combo: 1.0 1.0 1.014 -1.0 -0.057 done!
# Parameter combo: 1.0 1.0 1.014 -1.0 0.014 done!
# Parameter combo: 1.0 1.0 1.014 -1.0 0.086 done!
# Parameter combo: 1.0 1.0 1.014 -1.0 0.157 done!
# Parameter combo: 1.0 1.0 1.014 -1.0 0.229 done!
# Parameter combo: 1.0 1.0 1.014 -1.0 0.3 done!
# Parameter combo: 1.0 1.0 1.014 -0.714 -0.2 done!
# Parameter combo: 1.0 1.0 1.014 -0.714 -0.129 done!
# Parameter combo: 1.0 1.0 1.014 -0.714 -0.057 done!
# Parameter combo: 1.0 1.0 1.014 -0.714 0.014 done!
# Parameter combo: 1.0 1.0 1.014 -0.714 0.086 done!
# Parameter combo: 1.0 1.0 1.014 -0.714 0.157 done!
# Parameter combo: 1.0 1.0 1.014 -0.714 0.229 done!
# Parameter combo: 1.0 1.0 1.014 -0.714 0.3 done!
# Parameter combo: 1.0 1.0 1.014 -0.429 -0.2 done!
# Parameter combo: 1.0 1.0 1.014 -0.429 -0.129 done!
# Parameter combo: 1.0 1.0 1.014 -0.429 -0.057 done!
# Parameter combo: 1.0 1.0 1.014 -0.429 0.014 done!
# Parameter combo: 1.0 1.0 1.014 -0.429 0.086 done!
# Parameter combo: 1.0 1.0 1.014 -0.429 0.157 done!
# Parameter combo: 1.0 1.0 1.014 -0.429 0.229 done!
# Parameter combo: 1.0 1.0 1.014 -0.429 0.3 done!
# Parameter combo: 1.0 1.0 1.014 -0.143 -0.2 done!
# Parameter combo: 1.0 1.0 1.014 -0.143 -0.129 done!
# Parameter combo: 1.0 1.0 1.014 -0.143 -0.057 done!
# Parameter combo: 1.0 1.0 1.014 -0.143 0.014 done!
# Parameter combo: 1.0 1.0 1.014 -0.143 0.086 done!
# Parameter combo: 1.0 1.0 1.014 -0.143 0.157 done!
# Parameter combo: 1.0 1.0 1.014 -0.143 0.229 done!
# Parameter combo: 1.0 1.0 1.014 -0.143 0.3 done!
# Parameter combo: 1.0 1.0 1.014 0.143 -0.2 done!
# Parameter combo: 1.0 1.0 1.014 0.143 -0.129 done!
# Parameter combo: 1.0 1.0 1.014 0.143 -0.057 done!
# Parameter combo: 1.0 1.0 1.014 0.143 0.014 done!
# Parameter combo: 1.0 1.0 1.014 0.143 0.086 done!
# Parameter combo: 1.0 1.0 1.014 0.143 0.157 done!
# Parameter combo: 1.0 1.0 1.014 0.143 0.229 done!
# Parameter combo: 1.0 1.0 1.014 0.143 0.3 done!
# Parameter combo: 1.0 1.0 1.014 0.429 -0.2 done!
# Parameter combo: 1.0 1.0 1.014 0.429 -0.129 done!
# Parameter combo: 1.0 1.0 1.014 0.429 -0.057 done!
# Parameter combo: 1.0 1.0 1.014 0.429 0.014 done!
# Parameter combo: 1.0 1.0 1.014 0.429 0.086 done!
# Parameter combo: 1.0 1.0 1.014 0.429 0.157 done!
# Parameter combo: 1.0 1.0 1.014 0.429 0.229 done!
# Parameter combo: 1.0 1.0 1.014 0.429 0.3 done!
# Parameter combo: 1.0 1.0 1.014 0.714 -0.2 done!
# Parameter combo: 1.0 1.0 1.014 0.714 -0.129 done!
# Parameter combo: 1.0 1.0 1.014 0.714 -0.057 done!
# Parameter combo: 1.0 1.0 1.014 0.714 0.014 done!
# Parameter combo: 1.0 1.0 1.014 0.714 0.086 done!
# Parameter combo: 1.0 1.0 1.014 0.714 0.157 done!
# Parameter combo: 1.0 1.0 1.014 0.714 0.229 done!
# Parameter combo: 1.0 1.0 1.014 0.714 0.3 done!
# Parameter combo: 1.0 1.0 1.014 1.0 -0.2 done!
# Parameter combo: 1.0 1.0 1.014 1.0 -0.129 done!
# Parameter combo: 1.0 1.0 1.014 1.0 -0.057 done!
# Parameter combo: 1.0 1.0 1.014 1.0 0.014 done!
# Parameter combo: 1.0 1.0 1.014 1.0 0.086 done!
# Parameter combo: 1.0 1.0 1.014 1.0 0.157 done!
# Parameter combo: 1.0 1.0 1.014 1.0 0.229 done!
# Parameter combo: 1.0 1.0 1.014 1.0 0.3 done!
# Parameter combo: 1.0 1.0 1.043 -1.0 -0.2 done!
# Parameter combo: 1.0 1.0 1.043 -1.0 -0.129 done!
# Parameter combo: 1.0 1.0 1.043 -1.0 -0.057 done!
# Parameter combo: 1.0 1.0 1.043 -1.0 0.014 done!
# Parameter combo: 1.0 1.0 1.043 -1.0 0.086 done!
# Parameter combo: 1.0 1.0 1.043 -1.0 0.157 done!
# Parameter combo: 1.0 1.0 1.043 -1.0 0.229 done!
# Parameter combo: 1.0 1.0 1.043 -1.0 0.3 done!
# Parameter combo: 1.0 1.0 1.043 -0.714 -0.2 done!
# Parameter combo: 1.0 1.0 1.043 -0.714 -0.129 done!
# Parameter combo: 1.0 1.0 1.043 -0.714 -0.057 done!
# Parameter combo: 1.0 1.0 1.043 -0.714 0.014 done!
# Parameter combo: 1.0 1.0 1.043 -0.714 0.086 done!
# Parameter combo: 1.0 1.0 1.043 -0.714 0.157 done!
# Parameter combo: 1.0 1.0 1.043 -0.714 0.229 done!
# Parameter combo: 1.0 1.0 1.043 -0.714 0.3 done!
# Parameter combo: 1.0 1.0 1.043 -0.429 -0.2 done!
# Parameter combo: 1.0 1.0 1.043 -0.429 -0.129 done!
# Parameter combo: 1.0 1.0 1.043 -0.429 -0.057 done!
# Parameter combo: 1.0 1.0 1.043 -0.429 0.014 done!
# Parameter combo: 1.0 1.0 1.043 -0.429 0.086 done!
# Parameter combo: 1.0 1.0 1.043 -0.429 0.157 done!
# Parameter combo: 1.0 1.0 1.043 -0.429 0.229 done!
# Parameter combo: 1.0 1.0 1.043 -0.429 0.3 done!
# Parameter combo: 1.0 1.0 1.043 -0.143 -0.2 done!
# Parameter combo: 1.0 1.0 1.043 -0.143 -0.129 done!
# Parameter combo: 1.0 1.0 1.043 -0.143 -0.057 done!
# Parameter combo: 1.0 1.0 1.043 -0.143 0.014 done!
# Parameter combo: 1.0 1.0 1.043 -0.143 0.086 done!
# Parameter combo: 1.0 1.0 1.043 -0.143 0.157 done!
# Parameter combo: 1.0 1.0 1.043 -0.143 0.229 done!
# Parameter combo: 1.0 1.0 1.043 -0.143 0.3 done!
# Parameter combo: 1.0 1.0 1.043 0.143 -0.2 done!
# Parameter combo: 1.0 1.0 1.043 0.143 -0.129 done!
# Parameter combo: 1.0 1.0 1.043 0.143 -0.057 done!
# Parameter combo: 1.0 1.0 1.043 0.143 0.014 done!
# Parameter combo: 1.0 1.0 1.043 0.143 0.086 done!
# Parameter combo: 1.0 1.0 1.043 0.143 0.157 done!
# Parameter combo: 1.0 1.0 1.043 0.143 0.229 done!
# Parameter combo: 1.0 1.0 1.043 0.143 0.3 done!
# Parameter combo: 1.0 1.0 1.043 0.429 -0.2 done!
# Parameter combo: 1.0 1.0 1.043 0.429 -0.129 done!
# Parameter combo: 1.0 1.0 1.043 0.429 -0.057 done!
# Parameter combo: 1.0 1.0 1.043 0.429 0.014 done!
# Parameter combo: 1.0 1.0 1.043 0.429 0.086 done!
# Parameter combo: 1.0 1.0 1.043 0.429 0.157 done!
# Parameter combo: 1.0 1.0 1.043 0.429 0.229 done!
# Parameter combo: 1.0 1.0 1.043 0.429 0.3 done!
# Parameter combo: 1.0 1.0 1.043 0.714 -0.2 done!
# Parameter combo: 1.0 1.0 1.043 0.714 -0.129 done!
# Parameter combo: 1.0 1.0 1.043 0.714 -0.057 done!
# Parameter combo: 1.0 1.0 1.043 0.714 0.014 done!
# Parameter combo: 1.0 1.0 1.043 0.714 0.086 done!
# Parameter combo: 1.0 1.0 1.043 0.714 0.157 done!
# Parameter combo: 1.0 1.0 1.043 0.714 0.229 done!
# Parameter combo: 1.0 1.0 1.043 0.714 0.3 done!
# Parameter combo: 1.0 1.0 1.043 1.0 -0.2 done!
# Parameter combo: 1.0 1.0 1.043 1.0 -0.129 done!
# Parameter combo: 1.0 1.0 1.043 1.0 -0.057 done!
# Parameter combo: 1.0 1.0 1.043 1.0 0.014 done!
# Parameter combo: 1.0 1.0 1.043 1.0 0.086 done!
# Parameter combo: 1.0 1.0 1.043 1.0 0.157 done!
# Parameter combo: 1.0 1.0 1.043 1.0 0.229 done!
# Parameter combo: 1.0 1.0 1.043 1.0 0.3 done!
# Parameter combo: 1.0 1.0 1.071 -1.0 -0.2 done!
# Parameter combo: 1.0 1.0 1.071 -1.0 -0.129 done!
# Parameter combo: 1.0 1.0 1.071 -1.0 -0.057 done!
# Parameter combo: 1.0 1.0 1.071 -1.0 0.014 done!
# Parameter combo: 1.0 1.0 1.071 -1.0 0.086 done!
# Parameter combo: 1.0 1.0 1.071 -1.0 0.157 done!
# Parameter combo: 1.0 1.0 1.071 -1.0 0.229 done!
# Parameter combo: 1.0 1.0 1.071 -1.0 0.3 done!
# Parameter combo: 1.0 1.0 1.071 -0.714 -0.2 done!
# Parameter combo: 1.0 1.0 1.071 -0.714 -0.129 done!
# Parameter combo: 1.0 1.0 1.071 -0.714 -0.057 done!
# Parameter combo: 1.0 1.0 1.071 -0.714 0.014 done!
# Parameter combo: 1.0 1.0 1.071 -0.714 0.086 done!
# Parameter combo: 1.0 1.0 1.071 -0.714 0.157 done!
# Parameter combo: 1.0 1.0 1.071 -0.714 0.229 done!
# Parameter combo: 1.0 1.0 1.071 -0.714 0.3 done!
# Parameter combo: 1.0 1.0 1.071 -0.429 -0.2 done!
# Parameter combo: 1.0 1.0 1.071 -0.429 -0.129 done!
# Parameter combo: 1.0 1.0 1.071 -0.429 -0.057 done!
# Parameter combo: 1.0 1.0 1.071 -0.429 0.014 done!
# Parameter combo: 1.0 1.0 1.071 -0.429 0.086 done!
# Parameter combo: 1.0 1.0 1.071 -0.429 0.157 done!
# Parameter combo: 1.0 1.0 1.071 -0.429 0.229 done!
# Parameter combo: 1.0 1.0 1.071 -0.429 0.3 done!
# Parameter combo: 1.0 1.0 1.071 -0.143 -0.2 done!
# Parameter combo: 1.0 1.0 1.071 -0.143 -0.129 done!
# Parameter combo: 1.0 1.0 1.071 -0.143 -0.057 done!
# Parameter combo: 1.0 1.0 1.071 -0.143 0.014 done!
# Parameter combo: 1.0 1.0 1.071 -0.143 0.086 done!
# Parameter combo: 1.0 1.0 1.071 -0.143 0.157 done!
# Parameter combo: 1.0 1.0 1.071 -0.143 0.229 done!
# Parameter combo: 1.0 1.0 1.071 -0.143 0.3 done!
# Parameter combo: 1.0 1.0 1.071 0.143 -0.2 done!
# Parameter combo: 1.0 1.0 1.071 0.143 -0.129 done!
# Parameter combo: 1.0 1.0 1.071 0.143 -0.057 done!
# Parameter combo: 1.0 1.0 1.071 0.143 0.014 done!
# Parameter combo: 1.0 1.0 1.071 0.143 0.086 done!
# Parameter combo: 1.0 1.0 1.071 0.143 0.157 done!
# Parameter combo: 1.0 1.0 1.071 0.143 0.229 done!
# Parameter combo: 1.0 1.0 1.071 0.143 0.3 done!
# Parameter combo: 1.0 1.0 1.071 0.429 -0.2 done!
# Parameter combo: 1.0 1.0 1.071 0.429 -0.129 done!
# Parameter combo: 1.0 1.0 1.071 0.429 -0.057 done!
# Parameter combo: 1.0 1.0 1.071 0.429 0.014 done!
# Parameter combo: 1.0 1.0 1.071 0.429 0.086 done!
# Parameter combo: 1.0 1.0 1.071 0.429 0.157 done!
# Parameter combo: 1.0 1.0 1.071 0.429 0.229 done!
# Parameter combo: 1.0 1.0 1.071 0.429 0.3 done!
# Parameter combo: 1.0 1.0 1.071 0.714 -0.2 done!
# Parameter combo: 1.0 1.0 1.071 0.714 -0.129 done!
# Parameter combo: 1.0 1.0 1.071 0.714 -0.057 done!
# Parameter combo: 1.0 1.0 1.071 0.714 0.014 done!
# Parameter combo: 1.0 1.0 1.071 0.714 0.086 done!
# Parameter combo: 1.0 1.0 1.071 0.714 0.157 done!
# Parameter combo: 1.0 1.0 1.071 0.714 0.229 done!
# Parameter combo: 1.0 1.0 1.071 0.714 0.3 done!
# Parameter combo: 1.0 1.0 1.071 1.0 -0.2 done!
# Parameter combo: 1.0 1.0 1.071 1.0 -0.129 done!
# Parameter combo: 1.0 1.0 1.071 1.0 -0.057 done!
# Parameter combo: 1.0 1.0 1.071 1.0 0.014 done!
# Parameter combo: 1.0 1.0 1.071 1.0 0.086 done!
# Parameter combo: 1.0 1.0 1.071 1.0 0.157 done!
# Parameter combo: 1.0 1.0 1.071 1.0 0.229 done!
# Parameter combo: 1.0 1.0 1.071 1.0 0.3 done!
# Parameter combo: 1.0 1.0 1.1 -1.0 -0.2 done!
# Parameter combo: 1.0 1.0 1.1 -1.0 -0.129 done!
# Parameter combo: 1.0 1.0 1.1 -1.0 -0.057 done!
# Parameter combo: 1.0 1.0 1.1 -1.0 0.014 done!
# Parameter combo: 1.0 1.0 1.1 -1.0 0.086 done!
# Parameter combo: 1.0 1.0 1.1 -1.0 0.157 done!
# Parameter combo: 1.0 1.0 1.1 -1.0 0.229 done!
# Parameter combo: 1.0 1.0 1.1 -1.0 0.3 done!
# Parameter combo: 1.0 1.0 1.1 -0.714 -0.2 done!
# Parameter combo: 1.0 1.0 1.1 -0.714 -0.129 done!
# Parameter combo: 1.0 1.0 1.1 -0.714 -0.057 done!
# Parameter combo: 1.0 1.0 1.1 -0.714 0.014 done!
# Parameter combo: 1.0 1.0 1.1 -0.714 0.086 done!
# Parameter combo: 1.0 1.0 1.1 -0.714 0.157 done!
# Parameter combo: 1.0 1.0 1.1 -0.714 0.229 done!
# Parameter combo: 1.0 1.0 1.1 -0.714 0.3 done!
# Parameter combo: 1.0 1.0 1.1 -0.429 -0.2 done!
# Parameter combo: 1.0 1.0 1.1 -0.429 -0.129 done!
# Parameter combo: 1.0 1.0 1.1 -0.429 -0.057 done!
# Parameter combo: 1.0 1.0 1.1 -0.429 0.014 done!
# Parameter combo: 1.0 1.0 1.1 -0.429 0.086 done!
# Parameter combo: 1.0 1.0 1.1 -0.429 0.157 done!
# Parameter combo: 1.0 1.0 1.1 -0.429 0.229 done!
# Parameter combo: 1.0 1.0 1.1 -0.429 0.3 done!
# Parameter combo: 1.0 1.0 1.1 -0.143 -0.2 done!
# Parameter combo: 1.0 1.0 1.1 -0.143 -0.129 done!
# Parameter combo: 1.0 1.0 1.1 -0.143 -0.057 done!
# Parameter combo: 1.0 1.0 1.1 -0.143 0.014 done!
# Parameter combo: 1.0 1.0 1.1 -0.143 0.086 done!
# Parameter combo: 1.0 1.0 1.1 -0.143 0.157 done!
# Parameter combo: 1.0 1.0 1.1 -0.143 0.229 done!
# Parameter combo: 1.0 1.0 1.1 -0.143 0.3 done!
# Parameter combo: 1.0 1.0 1.1 0.143 -0.2 done!
# Parameter combo: 1.0 1.0 1.1 0.143 -0.129 done!
# Parameter combo: 1.0 1.0 1.1 0.143 -0.057 done!
# Parameter combo: 1.0 1.0 1.1 0.143 0.014 done!
# Parameter combo: 1.0 1.0 1.1 0.143 0.086 done!
# Parameter combo: 1.0 1.0 1.1 0.143 0.157 done!
# Parameter combo: 1.0 1.0 1.1 0.143 0.229 done!
# Parameter combo: 1.0 1.0 1.1 0.143 0.3 done!
# Parameter combo: 1.0 1.0 1.1 0.429 -0.2 done!
# Parameter combo: 1.0 1.0 1.1 0.429 -0.129 done!
# Parameter combo: 1.0 1.0 1.1 0.429 -0.057 done!
# Parameter combo: 1.0 1.0 1.1 0.429 0.014 done!
# Parameter combo: 1.0 1.0 1.1 0.429 0.086 done!
# Parameter combo: 1.0 1.0 1.1 0.429 0.157 done!
# Parameter combo: 1.0 1.0 1.1 0.429 0.229 done!
# Parameter combo: 1.0 1.0 1.1 0.429 0.3 done!
# Parameter combo: 1.0 1.0 1.1 0.714 -0.2 done!
# Parameter combo: 1.0 1.0 1.1 0.714 -0.129 done!
# Parameter combo: 1.0 1.0 1.1 0.714 -0.057 done!
# Parameter combo: 1.0 1.0 1.1 0.714 0.014 done!
# Parameter combo: 1.0 1.0 1.1 0.714 0.086 done!
# Parameter combo: 1.0 1.0 1.1 0.714 0.157 done!
# Parameter combo: 1.0 1.0 1.1 0.714 0.229 done!
# Parameter combo: 1.0 1.0 1.1 0.714 0.3 done!
# Parameter combo: 1.0 1.0 1.1 1.0 -0.2 done!
# Parameter combo: 1.0 1.0 1.1 1.0 -0.129 done!
# Parameter combo: 1.0 1.0 1.1 1.0 -0.057 done!
# Parameter combo: 1.0 1.0 1.1 1.0 0.014 done!
# Parameter combo: 1.0 1.0 1.1 1.0 0.086 done!
# Parameter combo: 1.0 1.0 1.1 1.0 0.157 done!
# Parameter combo: 1.0 1.0 1.1 1.0 0.229 done!
# Parameter combo: 1.0 1.0 1.1 1.0 0.3 done!
# FINISHED!

# %% [markdown]
# ### Example comparison

# %%
ok = OMKey(84,60,0)
pk = '90-100'

if smart_binning:
    tb = data_binned['bins'][pk][ok]
    time_bins = (tb[1:] + tb[:-1]) / 2
    
else:
    time_bins = time_bins[:-1]

# plot expectation
plt.figure()
y_hist = data_binned["truth"][pk][ok]
plt.step(time_bins, y_hist, where='mid', alpha=0.9)
plt.fill_between(time_bins, y_hist, step="mid", alpha=0.3, label='truth')
print('Expectation sum: %i' %sum(y_hist))

# compare with
params = "{sca}_{dome}_{p0}_{p1}_{_abs}".format(sca=1.00,dome=1.071,p0=-0.714 ,p1=0.3,_abs=1.00)
y_hist = data_binned["data"][params][pk][ok]
plt.step(time_bins, y_hist, where='mid', alpha=0.9)
plt.fill_between(time_bins, y_hist, step="mid", alpha=0.3, label="example data")

# format
plt.xlim(-100,4000)
plt.ylim(0,None)
plt.xlabel('Time [ns]', fontsize=14)
plt.ylabel('Number of hits', fontsize=14)
plt.legend(loc='upper right')

plt.tight_layout()
plt.savefig('example_comp.pdf')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# Expectation sum: 4941

# %% [markdown]
# # Computing the LLH-landsape
# For the likelihhod we combine the likelihoods of individual DOMs of all POCAM flashes. To keep it managable and keep the individual count statistic high, we only look at DOMs that are within a 100m radius around the corresponing POCAM.
# <br>
# The likelihood is then:
# $$
# \mathcal{L} = \prod_{\text{POCAMs}} \, \prod_{\text{DOMs} < 100m} \, \prod_{\text{histogram bins}} \, p(d_i, t_i)
# $$
# and the log llh:
# $$
# -2 ln \mathcal{L} = -2 \sum_{\text{POCAMs}} \, \sum_{\text{DOMs}} \, \sum_{\text{bins}} \, ln( p(d_i, t_i))
# $$
# If $t_i$ > 20:
# $$
# p(d_i,t_i) = Normal(d_i,t_i) = \frac{1}{\sqrt{2 \pi \sigma^2}} \, e^{-\frac{(d_i-t_i)^2}{2 \sigma^2}} \qquad \text{where} \quad \sigma^2 = \sqrt{t_i}^2 = t_i
# $$
# and if $t_i$ < 20:
# $$
#         p(d_i,t_i) = Poisson(d_i,t_i) = \frac{t_i^{d_i}}{d_i !} \, e^{-t_i}
# $$

# %%
n_data = 20 # number of datapoints taken after first hits

if smart_binning:
    n_data = n_bins_new

# %%
import llh_main
reload(llh_main)

# get 5-dimensional llh array
llh_arr5d = llh_main.llh_grid5d(data_binned, geo, 
                                scan_dict, truth_dict,
                                pocams, all_dom_keys,
                                smart_binning=True, n_data=n_data)
# Out:
# 1 / 512 combinations done.
# 2 / 512 combinations done.
# 3 / 512 combinations done.
# 4 / 512 combinations done.
# 5 / 512 combinations done.
# 6 / 512 combinations done.
# 7 / 512 combinations done.
# 8 / 512 combinations done.
# 9 / 512 combinations done.
# 10 / 512 combinations done.
# 11 / 512 combinations done.
# 12 / 512 combinations done.
# 13 / 512 combinations done.
# 14 / 512 combinations done.
# 15 / 512 combinations done.
# 16 / 512 combinations done.
# 17 / 512 combinations done.
# 18 / 512 combinations done.
# 19 / 512 combinations done.
# 20 / 512 combinations done.
# 21 / 512 combinations done.
# 22 / 512 combinations done.
# 23 / 512 combinations done.
# 24 / 512 combinations done.
# 25 / 512 combinations done.
# 26 / 512 combinations done.
# 27 / 512 combinations done.
# 28 / 512 combinations done.
# 29 / 512 combinations done.
# 30 / 512 combinations done.
# 31 / 512 combinations done.
# 32 / 512 combinations done.
# 33 / 512 combinations done.
# 34 / 512 combinations done.
# 35 / 512 combinations done.
# 36 / 512 combinations done.
# 37 / 512 combinations done.
# 38 / 512 combinations done.
# 39 / 512 combinations done.
# 40 / 512 combinations done.
# 41 / 512 combinations done.
# 42 / 512 combinations done.
# 43 / 512 combinations done.
# 44 / 512 combinations done.
# 45 / 512 combinations done.
# 46 / 512 combinations done.
# 47 / 512 combinations done.
# 48 / 512 combinations done.
# 49 / 512 combinations done.
# 50 / 512 combinations done.
# 51 / 512 combinations done.
# 52 / 512 combinations done.
# 53 / 512 combinations done.
# 54 / 512 combinations done.
# 55 / 512 combinations done.
# 56 / 512 combinations done.
# 57 / 512 combinations done.
# 58 / 512 combinations done.
# 59 / 512 combinations done.
# 60 / 512 combinations done.
# 61 / 512 combinations done.
# 62 / 512 combinations done.
# 63 / 512 combinations done.
# 64 / 512 combinations done.
# 65 / 512 combinations done.
# 66 / 512 combinations done.
# 67 / 512 combinations done.
# 68 / 512 combinations done.
# 69 / 512 combinations done.
# 70 / 512 combinations done.
# 71 / 512 combinations done.
# 72 / 512 combinations done.
# 73 / 512 combinations done.
# 74 / 512 combinations done.
# 75 / 512 combinations done.
# 76 / 512 combinations done.
# 77 / 512 combinations done.
# 78 / 512 combinations done.
# 79 / 512 combinations done.
# 80 / 512 combinations done.
# 81 / 512 combinations done.
# 82 / 512 combinations done.
# 83 / 512 combinations done.
# 84 / 512 combinations done.
# 85 / 512 combinations done.
# 86 / 512 combinations done.
# 87 / 512 combinations done.
# 88 / 512 combinations done.
# 89 / 512 combinations done.
# 90 / 512 combinations done.
# 91 / 512 combinations done.
# 92 / 512 combinations done.
# 93 / 512 combinations done.
# 94 / 512 combinations done.
# 95 / 512 combinations done.
# 96 / 512 combinations done.
# 97 / 512 combinations done.
# 98 / 512 combinations done.
# 99 / 512 combinations done.
# 100 / 512 combinations done.
# 101 / 512 combinations done.
# 102 / 512 combinations done.
# 103 / 512 combinations done.
# 104 / 512 combinations done.
# 105 / 512 combinations done.
# 106 / 512 combinations done.
# 107 / 512 combinations done.
# 108 / 512 combinations done.
# 109 / 512 combinations done.
# 110 / 512 combinations done.
# 111 / 512 combinations done.
# 112 / 512 combinations done.
# 113 / 512 combinations done.
# 114 / 512 combinations done.
# 115 / 512 combinations done.
# 116 / 512 combinations done.
# 117 / 512 combinations done.
# 118 / 512 combinations done.
# 119 / 512 combinations done.
# 120 / 512 combinations done.
# 121 / 512 combinations done.
# 122 / 512 combinations done.
# 123 / 512 combinations done.
# 124 / 512 combinations done.
# 125 / 512 combinations done.
# 126 / 512 combinations done.
# 127 / 512 combinations done.
# 128 / 512 combinations done.
# 129 / 512 combinations done.
# 130 / 512 combinations done.
# 131 / 512 combinations done.
# 132 / 512 combinations done.
# 133 / 512 combinations done.
# 134 / 512 combinations done.
# 135 / 512 combinations done.
# 136 / 512 combinations done.
# 137 / 512 combinations done.
# 138 / 512 combinations done.
# 139 / 512 combinations done.
# 140 / 512 combinations done.
# 141 / 512 combinations done.
# 142 / 512 combinations done.
# 143 / 512 combinations done.
# 144 / 512 combinations done.
# 145 / 512 combinations done.
# 146 / 512 combinations done.
# 147 / 512 combinations done.
# 148 / 512 combinations done.
# 149 / 512 combinations done.
# 150 / 512 combinations done.
# 151 / 512 combinations done.
# 152 / 512 combinations done.
# 153 / 512 combinations done.
# 154 / 512 combinations done.
# 155 / 512 combinations done.
# 156 / 512 combinations done.
# 157 / 512 combinations done.
# 158 / 512 combinations done.
# 159 / 512 combinations done.
# 160 / 512 combinations done.
# 161 / 512 combinations done.
# 162 / 512 combinations done.
# 163 / 512 combinations done.
# 164 / 512 combinations done.
# 165 / 512 combinations done.
# 166 / 512 combinations done.
# 167 / 512 combinations done.
# 168 / 512 combinations done.
# 169 / 512 combinations done.
# 170 / 512 combinations done.
# 171 / 512 combinations done.
# 172 / 512 combinations done.
# 173 / 512 combinations done.
# 174 / 512 combinations done.
# 175 / 512 combinations done.
# 176 / 512 combinations done.
# 177 / 512 combinations done.
# 178 / 512 combinations done.
# 179 / 512 combinations done.
# 180 / 512 combinations done.
# 181 / 512 combinations done.
# 182 / 512 combinations done.
# 183 / 512 combinations done.
# 184 / 512 combinations done.
# 185 / 512 combinations done.
# 186 / 512 combinations done.
# 187 / 512 combinations done.
# 188 / 512 combinations done.
# 189 / 512 combinations done.
# 190 / 512 combinations done.
# 191 / 512 combinations done.
# 192 / 512 combinations done.
# 193 / 512 combinations done.
# 194 / 512 combinations done.
# 195 / 512 combinations done.
# 196 / 512 combinations done.
# 197 / 512 combinations done.
# 198 / 512 combinations done.
# 199 / 512 combinations done.
# 200 / 512 combinations done.
# 201 / 512 combinations done.
# 202 / 512 combinations done.
# 203 / 512 combinations done.
# 204 / 512 combinations done.
# 205 / 512 combinations done.
# 206 / 512 combinations done.
# 207 / 512 combinations done.
# 208 / 512 combinations done.
# 209 / 512 combinations done.
# 210 / 512 combinations done.
# 211 / 512 combinations done.
# 212 / 512 combinations done.
# 213 / 512 combinations done.
# 214 / 512 combinations done.
# 215 / 512 combinations done.
# 216 / 512 combinations done.
# 217 / 512 combinations done.
# 218 / 512 combinations done.
# 219 / 512 combinations done.
# 220 / 512 combinations done.
# 221 / 512 combinations done.
# 222 / 512 combinations done.
# 223 / 512 combinations done.
# 224 / 512 combinations done.
# 225 / 512 combinations done.
# 226 / 512 combinations done.
# 227 / 512 combinations done.
# 228 / 512 combinations done.
# 229 / 512 combinations done.
# 230 / 512 combinations done.
# 231 / 512 combinations done.
# 232 / 512 combinations done.
# 233 / 512 combinations done.
# 234 / 512 combinations done.
# 235 / 512 combinations done.
# 236 / 512 combinations done.
# 237 / 512 combinations done.
# 238 / 512 combinations done.
# 239 / 512 combinations done.
# 240 / 512 combinations done.
# 241 / 512 combinations done.
# 242 / 512 combinations done.
# 243 / 512 combinations done.
# 244 / 512 combinations done.
# 245 / 512 combinations done.
# 246 / 512 combinations done.
# 247 / 512 combinations done.
# 248 / 512 combinations done.
# 249 / 512 combinations done.
# 250 / 512 combinations done.
# 251 / 512 combinations done.
# 252 / 512 combinations done.
# 253 / 512 combinations done.
# 254 / 512 combinations done.
# 255 / 512 combinations done.
# 256 / 512 combinations done.
# 257 / 512 combinations done.
# 258 / 512 combinations done.
# 259 / 512 combinations done.
# 260 / 512 combinations done.
# 261 / 512 combinations done.
# 262 / 512 combinations done.
# 263 / 512 combinations done.
# 264 / 512 combinations done.
# 265 / 512 combinations done.
# 266 / 512 combinations done.
# 267 / 512 combinations done.
# 268 / 512 combinations done.
# 269 / 512 combinations done.
# 270 / 512 combinations done.
# 271 / 512 combinations done.
# 272 / 512 combinations done.
# 273 / 512 combinations done.
# 274 / 512 combinations done.
# 275 / 512 combinations done.
# 276 / 512 combinations done.
# 277 / 512 combinations done.
# 278 / 512 combinations done.
# 279 / 512 combinations done.
# 280 / 512 combinations done.
# 281 / 512 combinations done.
# 282 / 512 combinations done.
# 283 / 512 combinations done.
# 284 / 512 combinations done.
# 285 / 512 combinations done.
# 286 / 512 combinations done.
# 287 / 512 combinations done.
# 288 / 512 combinations done.
# 289 / 512 combinations done.
# 290 / 512 combinations done.
# 291 / 512 combinations done.
# 292 / 512 combinations done.
# 293 / 512 combinations done.
# 294 / 512 combinations done.
# 295 / 512 combinations done.
# 296 / 512 combinations done.
# 297 / 512 combinations done.
# 298 / 512 combinations done.
# 299 / 512 combinations done.
# 300 / 512 combinations done.
# 301 / 512 combinations done.
# 302 / 512 combinations done.
# 303 / 512 combinations done.
# 304 / 512 combinations done.
# 305 / 512 combinations done.
# 306 / 512 combinations done.
# 307 / 512 combinations done.
# 308 / 512 combinations done.
# 309 / 512 combinations done.
# 310 / 512 combinations done.
# 311 / 512 combinations done.
# 312 / 512 combinations done.
# 313 / 512 combinations done.
# 314 / 512 combinations done.
# 315 / 512 combinations done.
# 316 / 512 combinations done.
# 317 / 512 combinations done.
# 318 / 512 combinations done.
# 319 / 512 combinations done.
# 320 / 512 combinations done.
# 321 / 512 combinations done.
# 322 / 512 combinations done.
# 323 / 512 combinations done.
# 324 / 512 combinations done.
# 325 / 512 combinations done.
# 326 / 512 combinations done.
# 327 / 512 combinations done.
# 328 / 512 combinations done.
# 329 / 512 combinations done.
# 330 / 512 combinations done.
# 331 / 512 combinations done.
# 332 / 512 combinations done.
# 333 / 512 combinations done.
# 334 / 512 combinations done.
# 335 / 512 combinations done.
# 336 / 512 combinations done.
# 337 / 512 combinations done.
# 338 / 512 combinations done.
# 339 / 512 combinations done.
# 340 / 512 combinations done.
# 341 / 512 combinations done.
# 342 / 512 combinations done.
# 343 / 512 combinations done.
# 344 / 512 combinations done.
# 345 / 512 combinations done.
# 346 / 512 combinations done.
# 347 / 512 combinations done.
# 348 / 512 combinations done.
# 349 / 512 combinations done.
# 350 / 512 combinations done.
# 351 / 512 combinations done.
# 352 / 512 combinations done.
# 353 / 512 combinations done.
# 354 / 512 combinations done.
# 355 / 512 combinations done.
# 356 / 512 combinations done.
# 357 / 512 combinations done.
# 358 / 512 combinations done.
# 359 / 512 combinations done.
# 360 / 512 combinations done.
# 361 / 512 combinations done.
# 362 / 512 combinations done.
# 363 / 512 combinations done.
# 364 / 512 combinations done.
# 365 / 512 combinations done.
# 366 / 512 combinations done.
# 367 / 512 combinations done.
# 368 / 512 combinations done.
# 369 / 512 combinations done.
# 370 / 512 combinations done.
# 371 / 512 combinations done.
# 372 / 512 combinations done.
# 373 / 512 combinations done.
# 374 / 512 combinations done.
# 375 / 512 combinations done.
# 376 / 512 combinations done.
# 377 / 512 combinations done.
# 378 / 512 combinations done.
# 379 / 512 combinations done.
# 380 / 512 combinations done.
# 381 / 512 combinations done.
# 382 / 512 combinations done.
# 383 / 512 combinations done.
# 384 / 512 combinations done.
# 385 / 512 combinations done.
# 386 / 512 combinations done.
# 387 / 512 combinations done.
# 388 / 512 combinations done.
# 389 / 512 combinations done.
# 390 / 512 combinations done.
# 391 / 512 combinations done.
# 392 / 512 combinations done.
# 393 / 512 combinations done.
# 394 / 512 combinations done.
# 395 / 512 combinations done.
# 396 / 512 combinations done.
# 397 / 512 combinations done.
# 398 / 512 combinations done.
# 399 / 512 combinations done.
# 400 / 512 combinations done.
# 401 / 512 combinations done.
# 402 / 512 combinations done.
# 403 / 512 combinations done.
# 404 / 512 combinations done.
# 405 / 512 combinations done.
# 406 / 512 combinations done.
# 407 / 512 combinations done.
# 408 / 512 combinations done.
# 409 / 512 combinations done.
# 410 / 512 combinations done.
# 411 / 512 combinations done.
# 412 / 512 combinations done.
# 413 / 512 combinations done.
# 414 / 512 combinations done.
# 415 / 512 combinations done.
# 416 / 512 combinations done.
# 417 / 512 combinations done.
# 418 / 512 combinations done.
# 419 / 512 combinations done.
# 420 / 512 combinations done.
# 421 / 512 combinations done.
# 422 / 512 combinations done.
# 423 / 512 combinations done.
# 424 / 512 combinations done.
# 425 / 512 combinations done.
# 426 / 512 combinations done.
# 427 / 512 combinations done.
# 428 / 512 combinations done.
# 429 / 512 combinations done.
# 430 / 512 combinations done.
# 431 / 512 combinations done.
# 432 / 512 combinations done.
# 433 / 512 combinations done.
# 434 / 512 combinations done.
# 435 / 512 combinations done.
# 436 / 512 combinations done.
# 437 / 512 combinations done.
# 438 / 512 combinations done.
# 439 / 512 combinations done.
# 440 / 512 combinations done.
# 441 / 512 combinations done.
# 442 / 512 combinations done.
# 443 / 512 combinations done.
# 444 / 512 combinations done.
# 445 / 512 combinations done.
# 446 / 512 combinations done.
# 447 / 512 combinations done.
# 448 / 512 combinations done.
# 449 / 512 combinations done.
# 450 / 512 combinations done.
# 451 / 512 combinations done.
# 452 / 512 combinations done.
# 453 / 512 combinations done.
# 454 / 512 combinations done.
# 455 / 512 combinations done.
# 456 / 512 combinations done.
# 457 / 512 combinations done.
# 458 / 512 combinations done.
# 459 / 512 combinations done.
# 460 / 512 combinations done.
# 461 / 512 combinations done.
# 462 / 512 combinations done.
# 463 / 512 combinations done.
# 464 / 512 combinations done.
# 465 / 512 combinations done.
# 466 / 512 combinations done.
# 467 / 512 combinations done.
# 468 / 512 combinations done.
# 469 / 512 combinations done.
# 470 / 512 combinations done.
# 471 / 512 combinations done.
# 472 / 512 combinations done.
# 473 / 512 combinations done.
# 474 / 512 combinations done.
# 475 / 512 combinations done.
# 476 / 512 combinations done.
# 477 / 512 combinations done.
# 478 / 512 combinations done.
# 479 / 512 combinations done.
# 480 / 512 combinations done.
# 481 / 512 combinations done.
# 482 / 512 combinations done.
# 483 / 512 combinations done.
# 484 / 512 combinations done.
# 485 / 512 combinations done.
# 486 / 512 combinations done.
# 487 / 512 combinations done.
# 488 / 512 combinations done.
# 489 / 512 combinations done.
# 490 / 512 combinations done.
# 491 / 512 combinations done.
# 492 / 512 combinations done.
# 493 / 512 combinations done.
# 494 / 512 combinations done.
# 495 / 512 combinations done.
# 496 / 512 combinations done.
# 497 / 512 combinations done.
# 498 / 512 combinations done.
# 499 / 512 combinations done.
# 500 / 512 combinations done.
# 501 / 512 combinations done.
# 502 / 512 combinations done.
# 503 / 512 combinations done.
# 504 / 512 combinations done.
# 505 / 512 combinations done.
# 506 / 512 combinations done.
# 507 / 512 combinations done.
# 508 / 512 combinations done.
# 509 / 512 combinations done.
# 510 / 512 combinations done.
# 511 / 512 combinations done.
# 512 / 512 combinations done.

# %%
# access different correlations via projected slices
# 0:abs 1:sca 2:domeff 3:p0 4:p1
# example: 2D sca vs domeff = array[0,:,:,0,0] for p0[0] parameter
# for GTCs project marginalized (minimum LLH slice) distributions
idx       = np.where(llh_arr5d == np.amin(llh_arr5d))
llh_array = llh_arr5d[idx[0][0],idx[1][0],:,idx[3][0],:]

# %%
import llh_main
reload(llh_main)

llh_main.plot2dgrid(scan_p1, scan_dome, llh_array, tx=t_p1, ty=t_dome)
# Out:
# <img src="data:image/png;base64,..." width="600">
# LLH minimum at sca, domeff: (0.086, 1.014)
# Truth at                  : (0.05, 1.01)

# %%
import llh_main
reload(llh_main)

llh_main.plot2dgrid(scan_p1, scan_dome, llh_array, tx=t_p1, ty=t_dome, interp=True)
# Out:
# <img src="data:image/png;base64,..." width="600">
# Truth at (x, y) : (0.05, 1.01)
# LLH min at      : (0.055, 1.004)
# x +- 1sig       : (0.03, 0.035)
# y +- 1sig       : (0.032, 0.018)

# %%
import llh_main
reload(llh_main)

llh_main.plotcorner(llh_arr5d, scan_dict, truth_dict, interp=True, interp_n=25)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
scan_abs
# Out:
# array([1.])

# %%
scan_sca
# Out:
# array([1.])

# %%
scan_dome
# Out:
# array([0.9  , 0.929, 0.957, 0.986, 1.014, 1.043, 1.071, 1.1  ])

# %%
scan_p0
# Out:
# array([-1.   , -0.714, -0.429, -0.143,  0.143,  0.429,  0.714,  1.   ])

# %%
scan_p1
# Out:
# array([-0.2  , -0.129, -0.057,  0.014,  0.086,  0.157,  0.229,  0.3  ])
